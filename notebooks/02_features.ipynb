# %% [markdown]
# # Hey Datathon 2026 — 02 · Feature Engineering
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mmateo101/hey-datathon-2026/blob/main/notebooks/02_features.ipynb)

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    sys.path.insert(0, '/content/drive/MyDrive/hey-datathon-2026/src')
    DATA_PATH = '/content/drive/MyDrive/hey-datathon-2026/data/raw/'
    PROCESSED_PATH = '/content/drive/MyDrive/hey-datathon-2026/data/processed/'
    # !pip install -q -r /content/drive/MyDrive/hey-datathon-2026/requirements.txt
else:
    DATA_PATH = '../data/raw/'
    PROCESSED_PATH = '../data/processed/'

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
