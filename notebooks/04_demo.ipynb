# %% [markdown]
# # Hey Datathon 2026 — 04 · Demo: Motor de Atención Personalizada
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mmateo101/hey-datathon-2026/blob/main/notebooks/04_demo.ipynb)

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    sys.path.insert(0, '/content/drive/MyDrive/hey-datathon-2026/src')
    BASE_PATH = '/content/drive/MyDrive/hey-datathon-2026/'
    # !pip install -q -r /content/drive/MyDrive/hey-datathon-2026/requirements.txt
else:
    BASE_PATH = '../'

# %%
import anthropic
import pandas as pd
from dotenv import load_dotenv
import os

if not IN_COLAB:
    load_dotenv()

client = anthropic.Anthropic(api_key=os.getenv('ANTHROPIC_API_KEY'))
